# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Q.13** **********************************

# %%
df_away = pd.read_parquet('../data/raw/parquets/match_away_team.parquet', engine = 'pyarrow')
df_home = pd.read_parquet('../data/raw/parquets/match_home_team.parquet', engine = 'pyarrow')

df_away.head()
# Out:
#    match_id                name                   slug gender  user_count  \
# 0  11998445  Auger-Aliassime F.  auger-aliassime-felix      M       23318
# 1  11998446          Cobolli F.         flavio-cobolli      M        5960
# 2  11998447         Martínez P.         martinez-pedro      M        2621
# 3  11998448           Muller A.       muller-alexandre      M        2443
# 4  11998449            Mayot H.           mayot-harold      M        1492
#
#              residence        birthplace  height  weight         plays  \
# 0  Monte Carlo, Monaco  Montreal, Canada    1.93    87.0  right-handed
# 1                 Rome   Florence, Italy    1.83    71.0  right-handed
# 2      Valencia, Spain     Alzira, Spain    1.85    76.0  right-handed
# 3               France    Poissy, France    1.83    73.0  right-handed
# 4        Marly, France      Metz, France    1.78    78.0  right-handed
#
#   turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
# 0       2017       218538.0   10166964.0     192013          30.0       AUG
# 1       None       171599.0     801778.0     273680          69.0       COB
# 2       2016        39448.0    2732689.0      77223         101.0       MAR
# 3       2014       106522.0    1178035.0      88992          81.0       MUL
# 4       None        65798.0     424547.0     248846         132.0       MAY
#
#   country               full_name
# 0  Canada  Auger-Aliassime, Felix
# 1   Italy          Flavio Cobolli
# 2   Spain         Martinez, Pedro
# 3  France       Muller, Alexandre
# 4  France           Mayot, Harold

# %%
df_home.head()
# Out:
#    match_id          name                slug gender  user_count  \
# 0  11998445     Cazaux A.       cazaux-arthur      M        4481
# 1  11998446  Lestienne C.  lestienne-constant      M        2034
# 2  11998447      Ćorić B.         coric-borna      M       12414
# 3  11998448       Mmoh M.        mmoh-michael      M        2206
# 4  11998449      Paire B.        paire-benoit      M        6089
#
#              residence            birthplace  height  weight         plays  \
# 0                 None   Montpellier, France    1.83     NaN  right-handed
# 1        Paris, France        Amiens, France    1.80    72.0  right-handed
# 2           Dubai, UAE       Zagreb, Croatia    1.88    85.0  right-handed
# 3   Bradenton, FL, USA  Riyadh, Saudi Arabia    1.88    90.0  right-handed
# 4  Geneva, Switzerland       Avignon, France    1.96    80.0  right-handed
#
#   turned_pro  current_prize  total_prize  player_id  current_rank name_code  \
# 0       None       233290.0     643582.0     287803          86.0       CAZ
# 1       2012        98577.0    1397804.0      62790          99.0       LES
# 2       2013       208593.0    9947986.0      64580          31.0       COR
# 3       2016        47928.0    1775118.0     131442         122.0       MMO
# 4       2007        33248.0    8622687.0      22218         110.0       PAI
#
#    country            full_name
# 0   France       Cazaux, Arthur
# 1   France  Lestienne, Constant
# 2  Croatia         Ćorić, Borna
# 3      USA        Mmoh, Michael
# 4   France        Paire, Benoit

# %%
print(len(df_home), len(df_away))
# Out:
# 12389 11690

# %%
Q_13_data = pd.concat([
    df_away[['player_id', 'plays']],
    df_home[['player_id', 'plays']]
]).drop_duplicates()

# %%
Q_13_data.head()
# Out:
#    player_id         plays
# 0     192013  right-handed
# 1     273680  right-handed
# 2      77223  right-handed
# 3      88992  right-handed
# 4     248846  right-handed

# %%
print(len(Q_13_data))
# Out:
# 2644

# %%
Q_13_data.to_parquet('../data/raw/parquets/Q_13_data.parquet')

# %% [markdown]
# **Q.15** *********************************

# %%
df_venue = pd.read_parquet('../data/raw/parquets/match_venue.parquet', engine = 'pyarrow')
df_venue.head()
# Out:
#    match_id       city           stadium  venue_id         country
# 0  11974049   Varazdin    Varazdin Arena      6310         Croatia
# 1  11974052   Kraljevo   Sport Hall Ibar     31876          Serbia
# 2  11974053  Groningen     Martini Plaza      7324     Netherlands
# 3  11974065     Trinec  Vitality Slezsko     43479  Czech Republic
# 4  11974066    Vilnius         SEB Arena     36345       Lithuania

# %%
distinct_countries = set(
                     list(df_away['country'])+
                     list(df_home['country'])+
                     list(df_venue['country']) )
Q_15_data = pd.DataFrame(list(distinct_countries), columns = ['countries'])
print(Q_15_data.head())
print(len(Q_15_data))
# Out:
#         countries
# 0  Czech Republic
# 1        Portugal
# 2         Morocco
# 3   New Caledonia
# 4           Malta
# 109

# %%
Q_15_data.to_parquet('../data/raw/parquets/Q_15_data.parquet')

# %% [markdown]
# ### **Q.17** ************************

# %%
df_power = pd.read_parquet('../data/raw/parquets/tennis_power_power.parquet', engine = 'pyarrow')
df_power.head()
# Out:
#    match_id  set_num  game_num  value  break_occurred
# 0  11998445        1         1 -52.80           False
# 1  11998445        1         2  48.14           False
# 2  11998445        1         3 -51.62           False
# 3  11998445        1         4  10.00           False
# 4  11998445        1         5  26.60            True

# %%
Q_17_data = df_power[['match_id', 'break_occurred']]
Q_17_data.head()
# Out:
#    match_id  break_occurred
# 0  11998445           False
# 1  11998445           False
# 2  11998445           False
# 3  11998445           False
# 4  11998445            True

# %%
Q_17_data.to_parquet('../data/raw/parquets/Q_17_data.parquet')
